# %%
isns.ImageGrid(x[-1][...,:1])
isns.ImageGrid(x_r[-4][...,:1])
isns.ImageGrid(x_r[-3][...,:1])
isns.ImageGrid(x_r[-2][...,:1])
isns.ImageGrid(x_r[-1][...,:1])

# %%
#randomly rotate each event by an angle between 0-360 degrees
#isns.ImageGrid(x[0][...,:1])
#isns.ImageGrid(scipy.ndimage.rotate(x[0][...,:1], 45, reshape=True, axes=(0,1),prefilter=False))

#angles that aren't multiples of 90 come out blurry
#prefilter=False, keeps the output image from coming out with tint

# %%
#create a plot of station coordinates to visualize

# get the coordinate points
sta2hex, hex2sta = data_tools.hexSquare()
#print(sta2hex)

#1 rotation (incomplete)
''''for key in sta2hex:
    if
    x = sta2hex[key][1]-3
    y = (sta2hex[key][0])*-1
    plt.plot(x, y) #increase axes
    #plt.text(x, y+0.5, key)
    plt.text(x, y+0.5, '({}, {})'.format(x, y))'''
    
#2 rotations, if statements that
''''x,y=0,4
w,z=-1,4
a,b=-2,4
c,d=-3,4
e,f=-4,4
g,h=-5,4
j,k=-5,3
m,n=-5,2
o,p=-5,1
r,s=-5,0
#u,v=-4,-1

for key in sta2hex:
    if int(key)<=6:
        plt.plot(x, y)
        plt.text(x, y+0.5, key)
        #plt.text(x, y+0.5, '({}, {})'.format(x, y))
        x+=1
        y-=1
    if int(key)>6 and int(key)<=13:
        plt.plot(w, z)
        plt.text(w, z+0.5, key)
        #plt.text(w, z+0.5, '({}, {})'.format(w, z))
        w+=1
        z-=1
    if int(key)>13 and int(key)<=21:
        plt.plot(a, b)
        plt.text(a, b+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        a+=1
        b-=1
    if int(key)> 21 and int(key)<=30:
        plt.plot(c, d)
        plt.text(c, d+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(c, d))
        c+=1
        d-=1
    if int(key)>30 and int(key)<=40:
        plt.plot(e, f)
        plt.text(e, f+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(e, f))
        e+=1
        f-=1
    if int(key)>40 and int(key)<=50:
        plt.plot(g, h)
        plt.text(g, h+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        g+=1
        h-=1
    if int(key)>50 and int(key)<=59:
        plt.plot(j, k)
        plt.text(j, k+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        j+=1
        k-=1
    if int(key)>59 and int(key)<=67:
        plt.plot(m, n)
        plt.text(m, n+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        m+=1
        n-=1
    if int(key)>67 and int(key)<=74:
        plt.plot(o, p)
        plt.text(o, p+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        o+=1
        p-=1
    if int(key)>74 and int(key)<=78:
        plt.plot(r, s)
        plt.text(r, s+0.5, key)
        #plt.text(a, b+0.5, '({}, {})'.format(a, b))
        r+=1
        s-=1 '''
        
# 3 rotations
''''for key in sta2hex:
    x = (sta2hex[key][0])*-1
    y = (sta2hex[key][1])*-1
    plt.plot(x, y) #increase axes
    #plt.text(x, y+0.5, key)
    plt.text(x, y+0.5, '({}, {})'.format(x, y))'''
    
# 4 rotations (incomplete)
''''for key in sta2hex:
    x = (sta2hex[key][1])*-1+4
    y = (sta2hex[key][0])-1
    plt.plot(x, y) #increase axes
    plt.text(x, y+0.5, key)
    #plt.text(x, y+0.5, '({}, {})'.format(x, y))'''
    

# how would i even incorporate these rotations?
# include param in HexSquare(), create if/switch statements, check that it falls within [-4,4] range

# %%
#load the data into a dictionay
#os.chmod('/Users/kmays/sim', stat.S_IREAD)
import chardet
#file_list=os.listdir('/Users/kmays/sim')
    
#files = [open("/Users/kmays/sim/sim_12360_00{}.npy".format(x), 'rb').read() for x in range(6)]
#files = [chardet.detect(file.read()) for file in files]
#print(files[0])
#result=chardet.detect(files[0])
#print(result[encoding])
#with open(filename, 'rb') as file:
 #   print(chardet.detect(files[0].read()))
#for file in files:
 #   print(chardet.detect(file.read()))
    
#hexDict=data_tools.load_data(files)

for file in file_list:

    with open(file,'rb') as f:
        data = f.read()  # or a chunk, f.read(1000000)
    encoding=chardet.detect(data).get("encoding")
    print(encoding)
