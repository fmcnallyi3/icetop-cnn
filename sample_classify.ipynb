# %% [markdown]
# Fashion MNIST Sample model

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
sample_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])
sample_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
sample_model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 943us/step - loss: 0.4958 - accuracy: 0.8276
# Epoch 2/10
# 1875/1875 [==============================] - 2s 932us/step - loss: 0.3719 - accuracy: 0.8645
# Epoch 3/10
# 1875/1875 [==============================] - 2s 948us/step - loss: 0.3353 - accuracy: 0.8778
# Epoch 4/10
# 1875/1875 [==============================] - 2s 916us/step - loss: 0.3129 - accuracy: 0.8861
# Epoch 5/10
# 1875/1875 [==============================] - 2s 898us/step - loss: 0.2944 - accuracy: 0.8919
# Epoch 6/10
# 1875/1875 [==============================] - 2s 902us/step - loss: 0.2833 - accuracy: 0.8959
# Epoch 7/10
# 1875/1875 [==============================] - 2s 901us/step - loss: 0.2691 - accuracy: 0.9020
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2596 - accuracy: 0.9036
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2478 - accuracy: 0.9081
# Epoch 10/10
# ...

# %%
test_loss, test_acc = sample_model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.3729 - accuracy: 0.8725 - 327ms/epoch - 1ms/step
#
# Test accuracy: 0.8725000023841858

# %%
predictions = sample_model.predict(test_images)

# %%
print(predictions)
# Out:
# [[-12.2702675 -16.20132   -14.029055  ...  -1.268813  -12.264604
#     3.9834995]
#  [  2.6775572 -24.148273   11.6505165 ... -24.178764  -13.102003
#   -29.045557 ]
#  [ -3.0688767  16.859295   -5.893057  ... -37.140892  -13.09728
#   -34.809326 ]
#  ...
#  [ -4.7244096 -14.982377   -7.036658  ... -13.608744   10.444312
#   -25.122992 ]
#  [ -9.824399   11.445472  -10.2345295 ... -12.6799345 -10.159708
#   -12.60107  ]
#  [ -6.0906796 -14.766102   -6.424071  ...  -1.4932516  -4.7620664
#    -8.179318 ]]
