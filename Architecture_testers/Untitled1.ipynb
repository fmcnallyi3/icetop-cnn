# %%
from Trainer import Trainer

# %%
train = Trainer()

# %%
for prep in train.data_preps:
    print(prep + ':' + str(train.data_preps[prep]))
# Out:
# Model_0:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': None, 'cosz': False}
# Model_1:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'plane', 'cosz': False}
# Model_2:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'plane', 'cosz': True}
# Model_3:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'laputop', 'cosz': False}
# Model_4:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'laputop', 'cosz': True}
# Model_5:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'small', 'cosz': False}
# Model_6:{'q': 'sum', 't': 'mean', 'normed': True, 'reco': 'small', 'cosz': True}
# Model_7:{'q': 'sum', 't': 'mean', 'normed': False, 'reco': None, 'cosz': False}
# Model_8:{'q': 'sum', 't': 'mean', 'normed': False, 'reco': 'plane', 'cosz': False}
# Model_9:{'q': 'sum', 't': 'mean', 'normed': False, 'reco': 'plane', 'cosz': True}
# Model_10:{'q': 'sum', 't': 'mean', 'normed': False, 'reco': 'laputop', 'cosz': False}
# ...
